# %%
# !pip install -q datasets huggingface_hub tqdm seaborn

# %%
import datasets
from datasets import Dataset, DatasetDict, load_dataset

from tqdm.notebook import tqdm
import numpy as np
import pandas as pd
import seaborn as sns
import os
import random

from nltk.translate.bleu_score import corpus_bleu
from nltk.translate.bleu_score import SmoothingFunction

# %%
# Dataset Arguments
dataset_id = 'ag_news'
label_column = 'label'
text_column = 'text'
encode_label = False # if label column is not encoded, set this flag to True

# Experiment Arguments
max_samples_per_class = 128
blue_threshold = 0.2
#output_dir = '/content/drive/MyDrive/Research/Folha/BLUE/Balanceamento de Dados/Dados/ag_news'
balanced_dataframe_filename = f'ag_news_balanced_dataset_blue_{max_samples_per_class}samples_{blue_threshold}threshold.csv'

# %%
def load_hf_dataset(dataset_id, label_column, text_column, encode_label):
  # load dataset
  dataset = load_dataset(dataset_id, split = 'train')

  if encode_label:
    dataset = dataset.class_encode_column(label_column)

  # rename label column to "label" if its different from this
  if label_column != 'label':
    dataset = dataset.rename_column(label_column, 'label')

  # rename text column to "text" if its different from this
  if text_column != 'text':
    dataset = dataset.rename_column(text_column, 'text')

  return dataset

# %%
dataset = load_hf_dataset(
    dataset_id = dataset_id,
    label_column = label_column,
    text_column = text_column,
    encode_label = encode_label
  )
# Out:
# Downloading builder script: 100%|██████████| 4.06k/4.06k [00:00<?, ?B/s]
# Downloading metadata: 100%|██████████| 2.65k/2.65k [00:00<?, ?B/s]
# Downloading readme: 100%|██████████| 7.95k/7.95k [00:00<?, ?B/s]
# Downloading data: 29.5MB [00:00, 50.0MB/s]
# Downloading data: 1.86MB [00:00, 10.2MB/s]
# Generating train split: 100%|██████████| 120000/120000 [00:02<00:00, 48829.19 examples/s]
# Generating test split: 100%|██████████| 7600/7600 [00:00<00:00, 46351.76 examples/s]

# %%
def blue_score(reference_text, generated_text):
    reference_summaries = [[reference_text]]
    generated_summaries = [generated_text]
    smoothie = SmoothingFunction().method4 # using smoothing method 4 as an example
    bleu_score = corpus_bleu(reference_summaries, generated_summaries, smoothing_function=smoothie)

    return bleu_score

# %%
blue_score("hello", "Hello helo hhello")
# Out:
# 0.21409092659758044

# %%
dataset
# Out:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 120000
# })

# %%
def select_samples(dataset):
    num_rows = len(dataset)
    select_indexes = []
    order_selected = []
    order_selected_class = []
    labels = dataset['label']
    labels_counter = {key : 0 for key in set(labels)}
    all_higher = False
    
    # First sample selection
    print("Selecting first sample...")
    first_sample_index = random.randint(0, num_rows - 1)
    labels_counter[labels[first_sample_index]] += 1
    select_indexes.append(first_sample_index)
    order_selected.append(1)
    order_selected_class.append(labels_counter[labels[first_sample_index]])
    last_sample_index = first_sample_index
    
    print("Started iteration for selection...")
    while not all_higher:
        candidate_index = random.randint(0, num_rows - 1)
        candidate = dataset[candidate_index]
        print(f"Candidate index: {candidate_index}")
        if (not candidate_index in select_indexes):
            reference_text = dataset[last_sample_index]["text"]
            candidate_text = dataset[candidate_index]["text"]
            score = blue_score(reference_text, candidate_text)
            if (score < blue_threshold):                
                labels_counter[labels[candidate_index]] += 1
                select_indexes.append(candidate_index)
                order_selected.append(len(select_indexes))
                order_selected_class.append(labels_counter[labels[candidate_index]])
                last_sample_index = candidate_index
                print(f"order selected: {len(select_indexes)}\torder selected class: {labels_counter[labels[candidate_index]]}")
        all_higher = all(value >= max_samples_per_class for value in labels_counter.values())
    print("Samples selected!")
    balanced_dataset = dataset.select(select_indexes)
    return balanced_dataset, select_indexes, order_selected, order_selected_class

# %%
balanced_dataset, select_indexes, order_selected, order_selected_class = select_samples(dataset)
# Out:
# Selecting first sample...
# Started iteration for selection...
# Candidate index: 70644
# order selected: 2	order selected class: 1
# Candidate index: 38593
# order selected: 3	order selected class: 1
# Candidate index: 118533
# order selected: 4	order selected class: 1
# Candidate index: 8503
# Candidate index: 77274
# Candidate index: 16013
# Candidate index: 81081
# order selected: 5	order selected class: 2
# Candidate index: 108083
# order selected: 6	order selected class: 3
# Candidate index: 107106
# order selected: 7	order selected class: 2
# Candidate index: 111668
# Candidate index: 115951
# order selected: 8	order selected class: 2
# Candidate index: 52031
# Candidate index: 83856
# order selected: 9	order selected class: 3
# Candidate index: 89911
# order selected: 10	order selected class: 4
# Candidate index: 108828
# order selected: 11	order selected class: 3
# Candidate index: 57185
# order selected: 12	order selected class: 4
# Candidate index: 69256
# order selected: 13	order selected class: 5
# Candidate index: 58119
# Candidate index: 53406
# order selected: 14	order selected class: 2
# Candidate index: 21287
# order selected: 15	order selected class: 6
# Candidate index: 85304
# order selected: 16	order selected class: 5
# Candidate index: 54845
# order selected: 17	order selected class: 3
# Candidate index: 7209
# order selected: 18	order selected class: 7
# Candidate index: 99103
# Candidate index: 59072
# order selected: 19	order selected class: 4
# Candidate index: 86825
# order selected: 20	order selected class: 5
# Candidate index: 17984
# Candidate index: 77421
# order selected: 21	order selected class: 6
# Candidate index: 85855
# order selected: 22	order selected class: 4
# Candidate index: 80090
# order selected: 23	order selected class: 8
# Candidate index: 7575
# Candidate index: 59321
# Candidate index: 56388
# Candidate index: 118104
# Candidate index: 39508
# order selected: 24	order selected class: 9
# Candidate index: 59824
# order selected: 25	order selected class: 5
# Candidate index: 13952
# Candidate index: 116807
# order selected: 26	order selected class: 10
# Candidate index: 45034
# order selected: 27	order selected class: 6
# Candidate index: 22329
# order selected: 28	order selected class: 7
# Candidate index: 90869
# Candidate index: 73485
# order selected: 29	order selected class: 6
# Candidate index: 8308
# Candidate index: 43918
# Candidate index: 113816
# Candidate index: 72907
# order selected: 30	order selected class: 7
# Candidate index: 64345
# order selected: 31	order selected class: 7
# Candidate index: 9743
# order selected: 32	order selected class: 8
# Candidate index: 114033
# Candidate index: 13245
# order selected: 33	order selected class: 11
# Candidate index: 5753
# Candidate index: 83883
# Candidate index: 117401
# order selected: 34	order selected class: 8
# Candidate index: 40892
# order selected: 35	order selected class: 8
# Candidate index: 117577
# order selected: 36	order selected class: 9
# Candidate index: 112031
# order selected: 37	order selected class: 12
# Candidate index: 47258
# order selected: 38	order selected class: 13
# Candidate index: 3021
# order selected: 39	order selected class: 14
# Candidate index: 64156
# order selected: 40	order selected class: 9
# Candidate index: 113127
# order selected: 41	order selected class: 15
# Candidate index: 44983
# order selected: 42	order selected class: 16
# Candidate index: 76615
# order selected: 43	order selected class: 10
# Candidate index: 11978
# order selected: 44	order selected class: 10
# Candidate index: 23917
# order selected: 45	order selected class: 11
# Candidate index: 4183
# order selected: 46	order selected class: 12
# Candidate index: 94085
# order selected: 47	order selected class: 17
# Candidate index: 111189
# Candidate index: 5396
# Candidate index: 115845
# order selected: 48	order selected class: 13
# Candidate index: 14088
# Candidate index: 77205
# order selected: 49	order selected class: 9
# Candidate index: 99878
# order selected: 50	order selected class: 18
# Candidate index: 16780
# order selected: 51	order selected class: 14
# Candidate index: 10740
# Candidate index: 45304
# order selected: 52	order selected class: 10
# Candidate index: 61297
# order selected: 53	order selected class: 11
# Candidate index: 13316
# order selected: 54	order selected class: 19
# Candidate index: 59591
# order selected: 55	order selected class: 11
# Candidate index: 27202
# order selected: 56	order selected class: 15
# Candidate index: 78745
# order selected: 57	order selected class: 12
# Candidate index: 78591
# Candidate index: 66914
# order selected: 58	order selected class: 20
# Candidate index: 102243
# order selected: 59	order selected class: 16
# Candidate index: 66879
# Candidate index: 114687
# Candidate index: 116036
# order selected: 60	order selected class: 21
# Candidate index: 52188
# order selected: 61	order selected class: 13
# Candidate index: 41404
# order selected: 62	order selected class: 12
# Candidate index: 538
# order selected: 63	order selected class: 17
# Candidate index: 95996
# order selected: 64	order selected class: 14
# Candidate index: 83498
# order selected: 65	order selected class: 18
# Candidate index: 64750
# order selected: 66	order selected class: 13
# Candidate index: 112793
# order selected: 67	order selected class: 15
# Candidate index: 36896
# order selected: 68	order selected class: 14
# Candidate index: 39293
# Candidate index: 5923
# order selected: 69	order selected class: 19
# Candidate index: 20267
# order selected: 70	order selected class: 15
# Candidate index: 98274
# order selected: 71	order selected class: 16
# Candidate index: 74899
# order selected: 72	order selected class: 17
# Candidate index: 18955
# order selected: 73	order selected class: 20
# Candidate index: 29703
# order selected: 74	order selected class: 16
# Candidate index: 18302
# order selected: 75	order selected class: 22
# Candidate index: 48577
# order selected: 76	order selected class: 18
# Candidate index: 41035
# Candidate index: 20815
# order selected: 77	order selected class: 17
# Candidate index: 92873
# order selected: 78	order selected class: 21
# Candidate index: 57836
# Candidate index: 53444
# order selected: 79	order selected class: 18
# Candidate index: 66799
# order selected: 80	order selected class: 23
# Candidate index: 113475
# order selected: 81	order selected class: 24
# Candidate index: 78004
# Candidate index: 81317
# Candidate index: 41565
# order selected: 82	order selected class: 19
# Candidate index: 74540
# order selected: 83	order selected class: 19
# Candidate index: 68936
# Candidate index: 23033
# Candidate index: 111642
# order selected: 84	order selected class: 20
# Candidate index: 112549
# order selected: 85	order selected class: 25
# Candidate index: 75179
# Candidate index: 3771
# order selected: 86	order selected class: 20
# Candidate index: 15823
# order selected: 87	order selected class: 21
# Candidate index: 80830
# order selected: 88	order selected class: 22
# Candidate index: 99315
# Candidate index: 116933
# Candidate index: 43179
# order selected: 89	order selected class: 21
# Candidate index: 44559
# order selected: 90	order selected class: 22
# Candidate index: 108272
# order selected: 91	order selected class: 22
# Candidate index: 89304
# Candidate index: 4347
# Candidate index: 17620
# order selected: 92	order selected class: 23
# Candidate index: 162
# order selected: 93	order selected class: 24
# Candidate index: 24682
# order selected: 94	order selected class: 23
# Candidate index: 91227
# order selected: 95	order selected class: 26
# Candidate index: 113168
# order selected: 96	order selected class: 24
# Candidate index: 77301
# order selected: 97	order selected class: 25
# Candidate index: 113085
# Candidate index: 16904
# order selected: 98	order selected class: 25
# Candidate index: 11337
# order selected: 99	order selected class: 27
# Candidate index: 7799
# order selected: 100	order selected class: 26
# Candidate index: 4368
# order selected: 101	order selected class: 28
# Candidate index: 40958
# order selected: 102	order selected class: 27
# Candidate index: 115776
# order selected: 103	order selected class: 28
# Candidate index: 109444
# order selected: 104	order selected class: 29
# Candidate index: 3443
# Candidate index: 56776
# Candidate index: 62297
# order selected: 105	order selected class: 29
# Candidate index: 18893
# order selected: 106	order selected class: 23
# Candidate index: 29159
# order selected: 107	order selected class: 24
# Candidate index: 60544
# order selected: 108	order selected class: 26
# Candidate index: 111887
# order selected: 109	order selected class: 27
# Candidate index: 38126
# order selected: 110	order selected class: 28
# Candidate index: 111930
# order selected: 111	order selected class: 29
# Candidate index: 88617
# order selected: 112	order selected class: 30
# Candidate index: 88020
# order selected: 113	order selected class: 25
# Candidate index: 22964
# Candidate index: 89892
# Candidate index: 95018
# Candidate index: 43020
# order selected: 114	order selected class: 31
# Candidate index: 81714
# order selected: 115	order selected class: 30
# Candidate index: 93520
# Candidate index: 54871
# Candidate index: 79917
# order selected: 116	order selected class: 31
# Candidate index: 18283
# Candidate index: 96631
# order selected: 117	order selected class: 30
# Candidate index: 63246
# order selected: 118	order selected class: 32
# Candidate index: 92420
# Candidate index: 102721
# order selected: 119	order selected class: 32
# Candidate index: 37341
# order selected: 120	order selected class: 33
# Candidate index: 38920
# order selected: 121	order selected class: 33
# Candidate index: 40829
# Candidate index: 97719
# order selected: 122	order selected class: 34
# Candidate index: 38892
# order selected: 123	order selected class: 26
# Candidate index: 118616
# order selected: 124	order selected class: 31
# Candidate index: 58272
# order selected: 125	order selected class: 27
# Candidate index: 30170
# Candidate index: 17267
# Candidate index: 43742
# Candidate index: 9235
# order selected: 126	order selected class: 34
# Candidate index: 74807
# order selected: 127	order selected class: 32
# Candidate index: 48817
# order selected: 128	order selected class: 35
# Candidate index: 46971
# Candidate index: 38925
# order selected: 129	order selected class: 28
# Candidate index: 69465
# Candidate index: 45766
# order selected: 130	order selected class: 29
# Candidate index: 76175
# order selected: 131	order selected class: 35
# Candidate index: 2248
# order selected: 132	order selected class: 30
# Candidate index: 95263
# order selected: 133	order selected class: 33
# Candidate index: 45986
# Candidate index: 116880
# Candidate index: 85495
# Candidate index: 104884
# Candidate index: 40127
# Candidate index: 35086
# order selected: 134	order selected class: 31
# Candidate index: 7215
# order selected: 135	order selected class: 36
# Candidate index: 12270
# order selected: 136	order selected class: 34
# Candidate index: 95171
# Candidate index: 82162
# order selected: 137	order selected class: 35
# Candidate index: 36684
# order selected: 138	order selected class: 37
# Candidate index: 12698
# order selected: 139	order selected class: 36
# Candidate index: 115393
# order selected: 140	order selected class: 36
# Candidate index: 101486
# order selected: 141	order selected class: 37
# Candidate index: 24648
# order selected: 142	order selected class: 37
# Candidate index: 79503
# order selected: 143	order selected class: 38
# Candidate index: 82304
# order selected: 144	order selected class: 39
# Candidate index: 20258
# order selected: 145	order selected class: 38
# Candidate index: 106978
# Candidate index: 62089
# order selected: 146	order selected class: 32
# Candidate index: 23592
# Candidate index: 60612
# Candidate index: 99164
# order selected: 147	order selected class: 40
# Candidate index: 87283
# order selected: 148	order selected class: 41
# Candidate index: 98831
# order selected: 149	order selected class: 39
# Candidate index: 21396
# Candidate index: 99188
# order selected: 150	order selected class: 40
# Candidate index: 16174
# order selected: 151	order selected class: 41
# Candidate index: 22594
# order selected: 152	order selected class: 42
# Candidate index: 103732
# order selected: 153	order selected class: 38
# Candidate index: 67784
# order selected: 154	order selected class: 42
# Candidate index: 37065
# order selected: 155	order selected class: 43
# Candidate index: 30186
# order selected: 156	order selected class: 33
# Candidate index: 36176
# order selected: 157	order selected class: 34
# Candidate index: 66583
# order selected: 158	order selected class: 44
# Candidate index: 100913
# order selected: 159	order selected class: 39
# Candidate index: 39158
# order selected: 160	order selected class: 40
# Candidate index: 107552
# order selected: 161	order selected class: 41
# Candidate index: 59732
# order selected: 162	order selected class: 45
# Candidate index: 113510
# order selected: 163	order selected class: 42
# Candidate index: 7501
# order selected: 164	order selected class: 35
# Candidate index: 51074
# order selected: 165	order selected class: 43
# Candidate index: 75478
# order selected: 166	order selected class: 36
# Candidate index: 117909
# Candidate index: 64676
# Candidate index: 105853
# order selected: 167	order selected class: 37
# Candidate index: 29587
# Candidate index: 12816
# Candidate index: 46386
# order selected: 168	order selected class: 46
# Candidate index: 5824
# order selected: 169	order selected class: 44
# Candidate index: 11529
# Candidate index: 116061
# order selected: 170	order selected class: 47
# Candidate index: 78849
# Candidate index: 97993
# order selected: 171	order selected class: 45
# Candidate index: 72412
# order selected: 172	order selected class: 43
# Candidate index: 81066
# Candidate index: 11313
# order selected: 173	order selected class: 38
# Candidate index: 4181
# order selected: 174	order selected class: 39
# Candidate index: 16195
# order selected: 175	order selected class: 44
# Candidate index: 29183
# order selected: 176	order selected class: 45
# Candidate index: 29791
# order selected: 177	order selected class: 46
# Candidate index: 22476
# order selected: 178	order selected class: 48
# Candidate index: 100593
# order selected: 179	order selected class: 49
# Candidate index: 63424
# order selected: 180	order selected class: 50
# Candidate index: 81650
# order selected: 181	order selected class: 46
# Candidate index: 117395
# order selected: 182	order selected class: 47
# Candidate index: 888
# Candidate index: 29000
# Candidate index: 26662
# Candidate index: 53990
# order selected: 183	order selected class: 40
# Candidate index: 102175
# order selected: 184	order selected class: 47
# Candidate index: 92732
# order selected: 185	order selected class: 41
# Candidate index: 88744
# order selected: 186	order selected class: 42
# Candidate index: 21529
# Candidate index: 51131
# order selected: 187	order selected class: 43
# Candidate index: 87084
# Candidate index: 79293
# Candidate index: 42643
# Candidate index: 550
# order selected: 188	order selected class: 51
# Candidate index: 77716
# Candidate index: 63696
# order selected: 189	order selected class: 48
# Candidate index: 71715
# Candidate index: 20257
# Candidate index: 1861
# order selected: 190	order selected class: 52
# Candidate index: 46345
# order selected: 191	order selected class: 48
# Candidate index: 107620
# Candidate index: 54330
# order selected: 192	order selected class: 44
# Candidate index: 89236
# Candidate index: 940
# order selected: 193	order selected class: 53
# Candidate index: 78522
# order selected: 194	order selected class: 49
# Candidate index: 103316
# Candidate index: 93902
# order selected: 195	order selected class: 50
# Candidate index: 114889
# order selected: 196	order selected class: 54
# Candidate index: 77794
# Candidate index: 53907
# order selected: 197	order selected class: 51
# Candidate index: 56566
# order selected: 198	order selected class: 49
# Candidate index: 19187
# order selected: 199	order selected class: 50
# Candidate index: 73028
# order selected: 200	order selected class: 51
# Candidate index: 41338
# Candidate index: 2316
# order selected: 201	order selected class: 52
# Candidate index: 62036
# order selected: 202	order selected class: 52
# Candidate index: 12168
# Candidate index: 51410
# order selected: 203	order selected class: 53
# Candidate index: 14191
# Candidate index: 2713
# Candidate index: 75906
# order selected: 204	order selected class: 55
# Candidate index: 48702
# order selected: 205	order selected class: 53
# Candidate index: 25280
# order selected: 206	order selected class: 54
# Candidate index: 91200
# Candidate index: 63921
# Candidate index: 87975
# order selected: 207	order selected class: 56
# Candidate index: 69931
# order selected: 208	order selected class: 55
# Candidate index: 85429
# order selected: 209	order selected class: 54
# Candidate index: 106350
# Candidate index: 73710
# Candidate index: 1199
# order selected: 210	order selected class: 57
# Candidate index: 79560
# order selected: 211	order selected class: 58
# Candidate index: 88046
# order selected: 212	order selected class: 55
# Candidate index: 61512
# Candidate index: 24953
# order selected: 213	order selected class: 56
# Candidate index: 86801
# order selected: 214	order selected class: 57
# Candidate index: 61442
# order selected: 215	order selected class: 45
# Candidate index: 8046
# order selected: 216	order selected class: 46
# Candidate index: 53349
# Candidate index: 81799
# Candidate index: 43872
# order selected: 217	order selected class: 47
# Candidate index: 70952
# order selected: 218	order selected class: 59
# Candidate index: 119055
# order selected: 219	order selected class: 48
# Candidate index: 36152
# order selected: 220	order selected class: 56
# Candidate index: 4417
# order selected: 221	order selected class: 58
# Candidate index: 21759
# Candidate index: 41102
# order selected: 222	order selected class: 49
# Candidate index: 39321
# order selected: 223	order selected class: 60
# Candidate index: 69669
# Candidate index: 90368
# order selected: 224	order selected class: 61
# Candidate index: 113504
# Candidate index: 63242
# Candidate index: 66533
# Candidate index: 44745
# order selected: 225	order selected class: 50
# Candidate index: 95926
# order selected: 226	order selected class: 51
# Candidate index: 96650
# Candidate index: 93879
# order selected: 227	order selected class: 57
# Candidate index: 6654
# order selected: 228	order selected class: 58
# Candidate index: 22563
# order selected: 229	order selected class: 62
# Candidate index: 75008
# order selected: 230	order selected class: 52
# Candidate index: 66270
# order selected: 231	order selected class: 59
# Candidate index: 69732
# order selected: 232	order selected class: 63
# Candidate index: 82643
# order selected: 233	order selected class: 64
# Candidate index: 3706
# Candidate index: 11622
# order selected: 234	order selected class: 60
# Candidate index: 77340
# order selected: 235	order selected class: 65
# Candidate index: 34515
# Candidate index: 90046
# Candidate index: 70586
# order selected: 236	order selected class: 59
# Candidate index: 114709
# Candidate index: 49702
# order selected: 237	order selected class: 60
# Candidate index: 71343
# order selected: 238	order selected class: 66
# Candidate index: 27260
# order selected: 239	order selected class: 67
# Candidate index: 20072
# order selected: 240	order selected class: 53
# Candidate index: 31190
# order selected: 241	order selected class: 61
# Candidate index: 25117
# order selected: 242	order selected class: 62
# Candidate index: 83943
# order selected: 243	order selected class: 61
# Candidate index: 41569
# order selected: 244	order selected class: 62
# Candidate index: 89999
# order selected: 245	order selected class: 63
# Candidate index: 5900
# order selected: 246	order selected class: 64
# Candidate index: 26454
# order selected: 247	order selected class: 68
# Candidate index: 90104
# order selected: 248	order selected class: 69
# Candidate index: 2472
# order selected: 249	order selected class: 70
# Candidate index: 41433
# order selected: 250	order selected class: 71
# Candidate index: 20363
# order selected: 251	order selected class: 63
# Candidate index: 40197
# order selected: 252	order selected class: 54
# Candidate index: 27533
# order selected: 253	order selected class: 72
# Candidate index: 74656
# order selected: 254	order selected class: 65
# Candidate index: 99608
# order selected: 255	order selected class: 66
# Candidate index: 107372
# Candidate index: 16369
# Candidate index: 45255
# Candidate index: 119696
# order selected: 256	order selected class: 55
# Candidate index: 47692
# order selected: 257	order selected class: 73
# Candidate index: 109131
# Candidate index: 100648
# order selected: 258	order selected class: 67
# Candidate index: 50803
# Candidate index: 104691
# Candidate index: 95954
# order selected: 259	order selected class: 68
# Candidate index: 94284
# order selected: 260	order selected class: 69
# Candidate index: 79065
# Candidate index: 87477
# order selected: 261	order selected class: 56
# Candidate index: 109445
# order selected: 262	order selected class: 57
# Candidate index: 33266
# Candidate index: 103611
# Candidate index: 117146
# order selected: 263	order selected class: 70
# Candidate index: 88493
# order selected: 264	order selected class: 64
# Candidate index: 112457
# order selected: 265	order selected class: 74
# Candidate index: 70642
# Candidate index: 95350
# Candidate index: 32963
# order selected: 266	order selected class: 71
# Candidate index: 81055
# order selected: 267	order selected class: 65
# Candidate index: 48078
# order selected: 268	order selected class: 66
# Candidate index: 115602
# order selected: 269	order selected class: 75
# Candidate index: 18258
# order selected: 270	order selected class: 67
# Candidate index: 106697
# order selected: 271	order selected class: 72
# Candidate index: 95332
# order selected: 272	order selected class: 76
# Candidate index: 44429
# order selected: 273	order selected class: 77
# Candidate index: 41662
# order selected: 274	order selected class: 68
# Candidate index: 80022
# order selected: 275	order selected class: 78
# Candidate index: 74887
# order selected: 276	order selected class: 69
# Candidate index: 73703
# order selected: 277	order selected class: 79
# Candidate index: 113811
# order selected: 278	order selected class: 73
# Candidate index: 97203
# order selected: 279	order selected class: 74
# Candidate index: 10905
# order selected: 280	order selected class: 58
# Candidate index: 15937
# order selected: 281	order selected class: 80
# Candidate index: 116603
# order selected: 282	order selected class: 59
# Candidate index: 116292
# order selected: 283	order selected class: 75
# Candidate index: 84030
# order selected: 284	order selected class: 60
# Candidate index: 83546
# order selected: 285	order selected class: 70
# Candidate index: 60422
# order selected: 286	order selected class: 61
# Candidate index: 58745
# order selected: 287	order selected class: 62
# Candidate index: 3247
# order selected: 288	order selected class: 81
# Candidate index: 113571
# order selected: 289	order selected class: 76
# Candidate index: 18553
# Candidate index: 28003
# order selected: 290	order selected class: 63
# Candidate index: 64861
# order selected: 291	order selected class: 82
# Candidate index: 9508
# order selected: 292	order selected class: 64
# Candidate index: 82545
# order selected: 293	order selected class: 71
# Candidate index: 10482
# Candidate index: 47150
# Candidate index: 36176
# Candidate index: 14983
# order selected: 294	order selected class: 83
# Candidate index: 67813
# order selected: 295	order selected class: 65
# Candidate index: 42276
# Candidate index: 99905
# Candidate index: 100745
# order selected: 296	order selected class: 66
# Candidate index: 110794
# order selected: 297	order selected class: 77
# Candidate index: 88699
# order selected: 298	order selected class: 78
# Candidate index: 92509
# order selected: 299	order selected class: 72
# Candidate index: 7027
# order selected: 300	order selected class: 67
# Candidate index: 34564
# order selected: 301	order selected class: 84
# Candidate index: 99756
# Candidate index: 89969
# order selected: 302	order selected class: 79
# Candidate index: 14464
# order selected: 303	order selected class: 85
# Candidate index: 107909
# order selected: 304	order selected class: 80
# Candidate index: 64164
# order selected: 305	order selected class: 73
# Candidate index: 100846
# Candidate index: 83130
# order selected: 306	order selected class: 74
# Candidate index: 81268
# Candidate index: 35744
# order selected: 307	order selected class: 86
# Candidate index: 119747
# order selected: 308	order selected class: 81
# Candidate index: 99386
# order selected: 309	order selected class: 68
# Candidate index: 86443
# Candidate index: 22965
# Candidate index: 15728
# Candidate index: 91184
# Candidate index: 94827
# Candidate index: 114111
# Candidate index: 86032
# Candidate index: 87910
# order selected: 310	order selected class: 87
# Candidate index: 54010
# order selected: 311	order selected class: 82
# Candidate index: 37570
# order selected: 312	order selected class: 83
# Candidate index: 43774
# order selected: 313	order selected class: 69
# Candidate index: 77960
# order selected: 314	order selected class: 75
# Candidate index: 55743
# order selected: 315	order selected class: 84
# Candidate index: 52090
# order selected: 316	order selected class: 88
# Candidate index: 84469
# order selected: 317	order selected class: 85
# Candidate index: 80459
# order selected: 318	order selected class: 89
# Candidate index: 53965
# order selected: 319	order selected class: 90
# Candidate index: 109151
# order selected: 320	order selected class: 70
# Candidate index: 35742
# order selected: 321	order selected class: 71
# Candidate index: 61469
# Candidate index: 57174
# order selected: 322	order selected class: 72
# Candidate index: 51059
# order selected: 323	order selected class: 76
# Candidate index: 86127
# order selected: 324	order selected class: 86
# Candidate index: 112063
# order selected: 325	order selected class: 87
# Candidate index: 78363
# order selected: 326	order selected class: 88
# Candidate index: 35583
# order selected: 327	order selected class: 77
# Candidate index: 85194
# order selected: 328	order selected class: 73
# Candidate index: 88197
# Candidate index: 65751
# Candidate index: 91083
# order selected: 329	order selected class: 74
# Candidate index: 3638
# Candidate index: 70909
# order selected: 330	order selected class: 75
# Candidate index: 86412
# order selected: 331	order selected class: 91
# Candidate index: 106347
# order selected: 332	order selected class: 76
# Candidate index: 46175
# order selected: 333	order selected class: 89
# Candidate index: 38628
# order selected: 334	order selected class: 78
# Candidate index: 20718
# order selected: 335	order selected class: 77
# Candidate index: 51939
# order selected: 336	order selected class: 90
# Candidate index: 98350
# order selected: 337	order selected class: 78
# Candidate index: 118269
# Candidate index: 79581
# order selected: 338	order selected class: 79
# Candidate index: 88351
# order selected: 339	order selected class: 92
# Candidate index: 34220
# order selected: 340	order selected class: 93
# Candidate index: 111114
# Candidate index: 111563
# order selected: 341	order selected class: 80
# Candidate index: 54559
# order selected: 342	order selected class: 79
# Candidate index: 46632
# order selected: 343	order selected class: 81
# Candidate index: 84224
# order selected: 344	order selected class: 91
# Candidate index: 70585
# Candidate index: 40790
# Candidate index: 62426
# Candidate index: 82084
# Candidate index: 96141
# order selected: 345	order selected class: 82
# Candidate index: 32429
# order selected: 346	order selected class: 80
# Candidate index: 65700
# Candidate index: 73780
# order selected: 347	order selected class: 94
# Candidate index: 108300
# order selected: 348	order selected class: 83
# Candidate index: 57912
# order selected: 349	order selected class: 92
# Candidate index: 49538
# order selected: 350	order selected class: 84
# Candidate index: 22287
# order selected: 351	order selected class: 93
# Candidate index: 115164
# order selected: 352	order selected class: 85
# Candidate index: 73797
# Candidate index: 62244
# Candidate index: 45846
# Candidate index: 29228
# order selected: 353	order selected class: 95
# Candidate index: 52226
# order selected: 354	order selected class: 96
# Candidate index: 40803
# order selected: 355	order selected class: 81
# Candidate index: 69901
# order selected: 356	order selected class: 94
# Candidate index: 61049
# order selected: 357	order selected class: 86
# Candidate index: 79301
# order selected: 358	order selected class: 87
# Candidate index: 10312
# Candidate index: 27383
# Candidate index: 31261
# Candidate index: 70150
# Candidate index: 77348
# order selected: 359	order selected class: 82
# Candidate index: 112565
# order selected: 360	order selected class: 97
# Candidate index: 87263
# order selected: 361	order selected class: 95
# Candidate index: 34242
# order selected: 362	order selected class: 88
# Candidate index: 24099
# order selected: 363	order selected class: 96
# Candidate index: 51702
# order selected: 364	order selected class: 89
# Candidate index: 92412
# order selected: 365	order selected class: 98
# Candidate index: 59428
# order selected: 366	order selected class: 97
# Candidate index: 6047
# order selected: 367	order selected class: 83
# Candidate index: 73899
# order selected: 368	order selected class: 98
# Candidate index: 90963
# Candidate index: 107281
# order selected: 369	order selected class: 99
# Candidate index: 72942
# order selected: 370	order selected class: 90
# Candidate index: 60166
# order selected: 371	order selected class: 91
# Candidate index: 90507
# order selected: 372	order selected class: 84
# Candidate index: 12427
# Candidate index: 71774
# order selected: 373	order selected class: 99
# Candidate index: 55665
# order selected: 374	order selected class: 100
# Candidate index: 38779
# Candidate index: 93554
# order selected: 375	order selected class: 100
# Candidate index: 107882
# order selected: 376	order selected class: 101
# Candidate index: 101490
# order selected: 377	order selected class: 102
# Candidate index: 38686
# Candidate index: 63410
# order selected: 378	order selected class: 92
# Candidate index: 103266
# order selected: 379	order selected class: 103
# Candidate index: 27501
# Candidate index: 85006
# Candidate index: 43662
# order selected: 380	order selected class: 93
# Candidate index: 89371
# order selected: 381	order selected class: 101
# Candidate index: 15481
# order selected: 382	order selected class: 85
# Candidate index: 88797
# order selected: 383	order selected class: 104
# Candidate index: 4933
# order selected: 384	order selected class: 94
# Candidate index: 40664
# order selected: 385	order selected class: 105
# Candidate index: 108633
# Candidate index: 105195
# order selected: 386	order selected class: 95
# Candidate index: 53107
# order selected: 387	order selected class: 96
# Candidate index: 17818
# order selected: 388	order selected class: 106
# Candidate index: 1836
# order selected: 389	order selected class: 102
# Candidate index: 5983
# order selected: 390	order selected class: 97
# Candidate index: 25557
# order selected: 391	order selected class: 86
# Candidate index: 47035
# order selected: 392	order selected class: 98
# Candidate index: 8317
# Candidate index: 50684
# Candidate index: 33150
# Candidate index: 38959
# Candidate index: 12713
# order selected: 393	order selected class: 107
# Candidate index: 21715
# order selected: 394	order selected class: 108
# Candidate index: 48358
# Candidate index: 88497
# Candidate index: 53407
# Candidate index: 119027
# Candidate index: 98019
# Candidate index: 51900
# Candidate index: 71713
# Candidate index: 46279
# Candidate index: 109626
# Candidate index: 40703
# order selected: 395	order selected class: 87
# Candidate index: 50934
# order selected: 396	order selected class: 99
# Candidate index: 73452
# Candidate index: 26020
# Candidate index: 44793
# Candidate index: 104123
# order selected: 397	order selected class: 88
# Candidate index: 72276
# Candidate index: 61426
# order selected: 398	order selected class: 109
# Candidate index: 4135
# order selected: 399	order selected class: 89
# Candidate index: 100037
# order selected: 400	order selected class: 100
# Candidate index: 15319
# Candidate index: 106160
# order selected: 401	order selected class: 90
# Candidate index: 88762
# Candidate index: 27497
# Candidate index: 8252
# order selected: 402	order selected class: 101
# Candidate index: 100083
# order selected: 403	order selected class: 103
# Candidate index: 97209
# order selected: 404	order selected class: 104
# Candidate index: 40810
# order selected: 405	order selected class: 102
# Candidate index: 96282
# order selected: 406	order selected class: 110
# Candidate index: 34428
# Candidate index: 1685
# order selected: 407	order selected class: 105
# Candidate index: 74158
# Candidate index: 13879
# Candidate index: 17878
# Candidate index: 57569
# Candidate index: 92383
# order selected: 408	order selected class: 106
# Candidate index: 87721
# Candidate index: 75061
# order selected: 409	order selected class: 111
# Candidate index: 43537
# order selected: 410	order selected class: 107
# Candidate index: 78412
# order selected: 411	order selected class: 91
# Candidate index: 95595
# Candidate index: 25580
# order selected: 412	order selected class: 92
# Candidate index: 20809
# order selected: 413	order selected class: 103
# Candidate index: 63544
# order selected: 414	order selected class: 93
# Candidate index: 77383
# order selected: 415	order selected class: 104
# Candidate index: 79061
# Candidate index: 55086
# order selected: 416	order selected class: 108
# Candidate index: 74572
# order selected: 417	order selected class: 109
# Candidate index: 12609
# order selected: 418	order selected class: 110
# Candidate index: 104656
# order selected: 419	order selected class: 105
# Candidate index: 84926
# Candidate index: 117491
# order selected: 420	order selected class: 111
# Candidate index: 92524
# Candidate index: 35390
# Candidate index: 31701
# order selected: 421	order selected class: 94
# Candidate index: 32444
# order selected: 422	order selected class: 95
# Candidate index: 105440
# order selected: 423	order selected class: 112
# Candidate index: 94167
# Candidate index: 114972
# order selected: 424	order selected class: 96
# Candidate index: 22401
# order selected: 425	order selected class: 106
# Candidate index: 3179
# Candidate index: 110783
# order selected: 426	order selected class: 113
# Candidate index: 2854
# Candidate index: 117286
# Candidate index: 116194
# order selected: 427	order selected class: 114
# Candidate index: 36753
# order selected: 428	order selected class: 107
# Candidate index: 22828
# order selected: 429	order selected class: 112
# Candidate index: 95578
# order selected: 430	order selected class: 108
# Candidate index: 97141
# order selected: 431	order selected class: 109
# Candidate index: 22487
# order selected: 432	order selected class: 110
# Candidate index: 53242
# order selected: 433	order selected class: 115
# Candidate index: 72002
# order selected: 434	order selected class: 97
# Candidate index: 110023
# order selected: 435	order selected class: 113
# Candidate index: 83786
# Candidate index: 77859
# Candidate index: 81271
# order selected: 436	order selected class: 114
# Candidate index: 100478
# order selected: 437	order selected class: 116
# Candidate index: 50324
# order selected: 438	order selected class: 115
# Candidate index: 114289
# order selected: 439	order selected class: 117
# Candidate index: 20764
# order selected: 440	order selected class: 98
# Candidate index: 41984
# order selected: 441	order selected class: 111
# Candidate index: 111892
# order selected: 442	order selected class: 99
# Candidate index: 99027
# Candidate index: 74484
# Candidate index: 55381
# Candidate index: 2476
# Candidate index: 45687
# order selected: 443	order selected class: 116
# Candidate index: 23991
# order selected: 444	order selected class: 118
# Candidate index: 23262
# Candidate index: 47542
# order selected: 445	order selected class: 112
# Candidate index: 85862
# order selected: 446	order selected class: 113
# Candidate index: 40796
# order selected: 447	order selected class: 100
# Candidate index: 91809
# order selected: 448	order selected class: 114
# Candidate index: 16246
# order selected: 449	order selected class: 101
# Candidate index: 8791
# order selected: 450	order selected class: 115
# Candidate index: 11876
# order selected: 451	order selected class: 102
# Candidate index: 105430
# order selected: 452	order selected class: 117
# Candidate index: 30346
# Candidate index: 51080
# order selected: 453	order selected class: 118
# Candidate index: 2440
# order selected: 454	order selected class: 119
# Candidate index: 94478
# order selected: 455	order selected class: 116
# Candidate index: 117438
# order selected: 456	order selected class: 120
# Candidate index: 38228
# order selected: 457	order selected class: 117
# Candidate index: 55038
# order selected: 458	order selected class: 121
# Candidate index: 95192
# Candidate index: 12558
# order selected: 459	order selected class: 119
# Candidate index: 20330
# order selected: 460	order selected class: 120
# Candidate index: 101797
# order selected: 461	order selected class: 103
# Candidate index: 13476
# Candidate index: 98212
# order selected: 462	order selected class: 104
# Candidate index: 65384
# order selected: 463	order selected class: 118
# Candidate index: 37330
# order selected: 464	order selected class: 105
# Candidate index: 3121
# order selected: 465	order selected class: 121
# Candidate index: 3784
# order selected: 466	order selected class: 122
# Candidate index: 14241
# Candidate index: 110316
# order selected: 467	order selected class: 119
# Candidate index: 59679
# order selected: 468	order selected class: 120
# Candidate index: 44814
# Candidate index: 53522
# order selected: 469	order selected class: 122
# Candidate index: 45562
# order selected: 470	order selected class: 121
# Candidate index: 33855
# Candidate index: 108157
# order selected: 471	order selected class: 123
# Candidate index: 48139
# order selected: 472	order selected class: 122
# Candidate index: 102611
# Candidate index: 117195
# order selected: 473	order selected class: 106
# Candidate index: 99360
# order selected: 474	order selected class: 124
# Candidate index: 16822
# order selected: 475	order selected class: 107
# Candidate index: 49887
# order selected: 476	order selected class: 108
# Candidate index: 115903
# Candidate index: 49448
# order selected: 477	order selected class: 125
# Candidate index: 63516
# order selected: 478	order selected class: 123
# Candidate index: 88650
# order selected: 479	order selected class: 124
# Candidate index: 115676
# order selected: 480	order selected class: 123
# Candidate index: 4804
# order selected: 481	order selected class: 109
# Candidate index: 8281
# Candidate index: 6244
# Candidate index: 108502
# Candidate index: 55484
# Candidate index: 89669
# order selected: 482	order selected class: 125
# Candidate index: 68291
# order selected: 483	order selected class: 126
# Candidate index: 96029
# order selected: 484	order selected class: 126
# Candidate index: 100184
# order selected: 485	order selected class: 127
# Candidate index: 58031
# Candidate index: 12287
# order selected: 486	order selected class: 128
# Candidate index: 115333
# Candidate index: 77289
# Candidate index: 54684
# order selected: 487	order selected class: 124
# Candidate index: 38828
# order selected: 488	order selected class: 125
# Candidate index: 82937
# order selected: 489	order selected class: 129
# Candidate index: 71974
# order selected: 490	order selected class: 127
# Candidate index: 62546
# order selected: 491	order selected class: 130
# Candidate index: 67450
# order selected: 492	order selected class: 131
# Candidate index: 21610
# order selected: 493	order selected class: 132
# Candidate index: 29969
# order selected: 494	order selected class: 126
# Candidate index: 72672
# Candidate index: 29185
# order selected: 495	order selected class: 127
# Candidate index: 1827
# order selected: 496	order selected class: 128
# Candidate index: 455
# order selected: 497	order selected class: 133
# Candidate index: 4570
# order selected: 498	order selected class: 134
# Candidate index: 17157
# Candidate index: 4600
# order selected: 499	order selected class: 128
# Candidate index: 44379
# order selected: 500	order selected class: 110
# Candidate index: 17218
# Candidate index: 90131
# order selected: 501	order selected class: 129
# Candidate index: 116538
# Candidate index: 85166
# order selected: 502	order selected class: 111
# Candidate index: 21874
# order selected: 503	order selected class: 129
# Candidate index: 104183
# order selected: 504	order selected class: 130
# Candidate index: 116943
# order selected: 505	order selected class: 130
# Candidate index: 35309
# Candidate index: 77242
# order selected: 506	order selected class: 112
# Candidate index: 67424
# order selected: 507	order selected class: 131
# Candidate index: 47047
# order selected: 508	order selected class: 132
# Candidate index: 13701
# order selected: 509	order selected class: 113
# Candidate index: 59260
# order selected: 510	order selected class: 133
# Candidate index: 84122
# order selected: 511	order selected class: 135
# Candidate index: 4713
# order selected: 512	order selected class: 114
# Candidate index: 47384
# Candidate index: 115098
# Candidate index: 93043
# Candidate index: 9471
# order selected: 513	order selected class: 131
# Candidate index: 76861
# order selected: 514	order selected class: 136
# Candidate index: 82016
# order selected: 515	order selected class: 134
# Candidate index: 33106
# order selected: 516	order selected class: 132
# Candidate index: 28955
# Candidate index: 78955
# Candidate index: 105597
# order selected: 517	order selected class: 137
# Candidate index: 1069
# Candidate index: 18645
# Candidate index: 98100
# Candidate index: 47789
# Candidate index: 113483
# Candidate index: 316
# order selected: 518	order selected class: 135
# Candidate index: 94836
# order selected: 519	order selected class: 133
# Candidate index: 47660
# Candidate index: 48120
# order selected: 520	order selected class: 115
# Candidate index: 40626
# Candidate index: 63968
# Candidate index: 37480
# order selected: 521	order selected class: 116
# Candidate index: 33775
# Candidate index: 50377
# order selected: 522	order selected class: 134
# Candidate index: 44700
# order selected: 523	order selected class: 117
# Candidate index: 58967
# order selected: 524	order selected class: 138
# Candidate index: 115852
# Candidate index: 98718
# order selected: 525	order selected class: 118
# Candidate index: 9086
# order selected: 526	order selected class: 135
# Candidate index: 69789
# order selected: 527	order selected class: 136
# Candidate index: 2241
# order selected: 528	order selected class: 119
# Candidate index: 48448
# order selected: 529	order selected class: 136
# Candidate index: 73074
# Candidate index: 87645
# Candidate index: 105135
# Candidate index: 114087
# Candidate index: 45819
# Candidate index: 32564
# Candidate index: 37691
# order selected: 530	order selected class: 137
# Candidate index: 21791
# Candidate index: 76041
# order selected: 531	order selected class: 139
# Candidate index: 111643
# order selected: 532	order selected class: 137
# Candidate index: 115686
# Candidate index: 81352
# Candidate index: 80231
# order selected: 533	order selected class: 140
# Candidate index: 90871
# order selected: 534	order selected class: 141
# Candidate index: 95956
# order selected: 535	order selected class: 120
# Candidate index: 37714
# order selected: 536	order selected class: 121
# Candidate index: 45362
# order selected: 537	order selected class: 138
# Candidate index: 87428
# order selected: 538	order selected class: 142
# Candidate index: 117719
# order selected: 539	order selected class: 143
# Candidate index: 103631
# order selected: 540	order selected class: 138
# Candidate index: 45186
# Candidate index: 113038
# order selected: 541	order selected class: 139
# Candidate index: 27594
# order selected: 542	order selected class: 122
# Candidate index: 104180
# order selected: 543	order selected class: 144
# Candidate index: 71206
# order selected: 544	order selected class: 140
# Candidate index: 72922
# order selected: 545	order selected class: 141
# Candidate index: 85573
# order selected: 546	order selected class: 142
# Candidate index: 78837
# order selected: 547	order selected class: 139
# Candidate index: 119368
# order selected: 548	order selected class: 143
# Candidate index: 98396
# order selected: 549	order selected class: 145
# Candidate index: 44119
# order selected: 550	order selected class: 144
# Candidate index: 74324
# Candidate index: 89726
# order selected: 551	order selected class: 140
# Candidate index: 67485
# order selected: 552	order selected class: 141
# Candidate index: 51665
# Candidate index: 76145
# order selected: 553	order selected class: 145
# Candidate index: 99323
# order selected: 554	order selected class: 142
# Candidate index: 64244
# order selected: 555	order selected class: 146
# Candidate index: 18442
# order selected: 556	order selected class: 146
# Candidate index: 64346
# order selected: 557	order selected class: 123
# Candidate index: 22211
# order selected: 558	order selected class: 143
# Candidate index: 112359
# order selected: 559	order selected class: 147
# Candidate index: 44488
# Candidate index: 90120
# Candidate index: 51576
# Candidate index: 18180
# order selected: 560	order selected class: 124
# Candidate index: 80357
# Candidate index: 78526
# order selected: 561	order selected class: 125
# Candidate index: 85134
# order selected: 562	order selected class: 144
# Candidate index: 114392
# order selected: 563	order selected class: 126
# Candidate index: 39774
# order selected: 564	order selected class: 148
# Candidate index: 74728
# order selected: 565	order selected class: 145
# Candidate index: 23803
# order selected: 566	order selected class: 146
# Candidate index: 45872
# Candidate index: 7309
# order selected: 567	order selected class: 127
# Candidate index: 1575
# Candidate index: 114322
# order selected: 568	order selected class: 147
# Candidate index: 37150
# Candidate index: 85520
# order selected: 569	order selected class: 148
# Candidate index: 24766
# order selected: 570	order selected class: 149
# Candidate index: 71867
# Candidate index: 82890
# order selected: 571	order selected class: 149
# Candidate index: 48459
# order selected: 572	order selected class: 147
# Candidate index: 15228
# order selected: 573	order selected class: 150
# Candidate index: 110190
# Candidate index: 80993
# Candidate index: 13596
# order selected: 574	order selected class: 148
# Candidate index: 68879
# order selected: 575	order selected class: 151
# Candidate index: 113137
# Candidate index: 105358
# Candidate index: 11309
# Candidate index: 8550
# Candidate index: 36701
# order selected: 576	order selected class: 152
# Candidate index: 74420
# order selected: 577	order selected class: 153
# Candidate index: 51329
# order selected: 578	order selected class: 149
# Candidate index: 48193
# order selected: 579	order selected class: 150
# Candidate index: 29023
# order selected: 580	order selected class: 128
# Samples selected!

# %%
def create_df(dataset, order_selected, order_selected_class, filepath):
  if os.path.exists(filepath):
    df = pd.read_csv(filepath)
  else:
    df = dataset.to_pandas()
    df['order_selected'] = order_selected
    df['order_selected_class'] = order_selected_class

    df.to_csv(filepath, index = False)

  return df

# %%
dataframe_filepath = os.path.join(os.getcwd(), balanced_dataframe_filename)
df_balanced = create_df(
    dataset = balanced_dataset,
    order_selected = order_selected,
    order_selected_class = order_selected_class,
    filepath = dataframe_filepath
)
